# %% [markdown]
# # @property装饰器

# %%
class Person(object):
    def __init__(self, name, age):
        self._name = name
        self._age = age
    
    @property
    def name(self):
        return self.name
    
    @property
    def age(self):
        return self._age
    
    @age.setter
    def age(self, age):
        self._age = age
    
    def play(self):
        if self._age <= 16:
            print("%s is playing toy" % self._name)
        else:
            print("%s is playing sm" % self._name)
def main():
    person = Person("WangDaChui", 12)
    person.play()
    person.age = 22
    person.play()

if __name__ == '__main__':
    main()
# Out:
# WangDaChui is playing toy
# WangDaChui is playing sm

# %% [markdown]
# # __slots__魔法

# %%
class Person(object):
    __slots__ =('_name','_age','_gender')
    
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    @property
    def name(self):
        return self._name
    
    @property
    def age(self):
        return self._age
    
    @age.setter
    def age(self, age):
        self._age = age
    
    def play(self):
        if self._age <16:
            print("% is playing toy" % self._name)
        else:
            print("%s is playing sm" % self._name)
def main():
    person = Person("wangdachui", 22)
    person.play()
    person._gender = 'man'
    
if __name__ == '__main__':
    main()
# Out:
# wangdachui is playing sm

# %% [markdown]
# # 静态方法和类方法

# %%
from math import sqrt
class Triangle(object):
    def __init__(self,a,b,c):
        self._a = a
        self._b = b
        self._c = c
    
    @staticmethod
    def is_valid(a, b, c):
        return a+b>c and b+c>a and a+c>b
    
    def perimeter(self):
        return self._a +self._b +self._c
    
    def area(self):
        half = self.perimeter()/2
        return sqrt(half * (half-self._a) * (half-self._b) * (half-self._c))
    
def main():
    a,b,c = 3,4,5
    if Triangle.is_valid(a,b,c):
        t = Triangle(a,b,c)
        print(t.perimeter())
        print(t.area())
    else:
        print("can not form triangle")

if __name__ == "__main__":
    main()
# Out:
# 12
# 6.0

# %% [markdown]
# # 类方法

# %%
from time import time, localtime, sleep

class Clock(object):
    def __init__(self, hour=0, minute=0, second=0):
        self._hour = hour
        self._minute = minute
        self._second = second
    
    @classmethod
    def now(cls):
        ctime = localtime(time())
        return cls(ctime.tm_hour, ctime.tm_min, ctime.tm_sec)
    
    def run(self):
        self._second +=1
        if self._second == 60:
            self._second=0
            self._minute +=1
            if self._minute == 60:
                self._mintue = 0
                self._hour +=1
                if self._hour == 24:
                    self._hour = 0
    def show(self):
        return "%02d : %02d : %02d" % (self._hour, self._minute, self._second)

def main():
    clock = Clock.now()
    while(True):
        print(clock.show())
        sleep(1)
        clock.run()
if __name__ == '__main__':
    main()
# Out:
# 11 : 16 : 41
# 11 : 16 : 42
# 11 : 16 : 43
# 11 : 16 : 44
# 11 : 16 : 45
# 11 : 16 : 46
# 11 : 16 : 47
# 11 : 16 : 48
# 11 : 16 : 49
# 11 : 16 : 50
# 11 : 16 : 51
# 11 : 16 : 52
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-655eaa4bbe77> in <module>
#      32         clock.run()
#      33 if __name__ == '__main__':
# ---> 34     main()
#
# <ipython-input-2-655eaa4bbe77> in main()
#      29     while(True):
#      30         print(clock.show())
# ---> 31         sleep(1)
#      32         clock.run()
#      33 if __name__ == '__main__':
#
# KeyboardInterrupt:

# %% [markdown]
# # 继承和多态

# %%
class Person(object):
    def __init__(self, name, age):
        self._name = name
        self._age = age
    
    @property
    def name(self):
        return self._name
    
    @property
    def age(self):
        return self._age
    
    @age.setter
    def age(self, age):
        self._age = age
        
    def play(self):
        print("%s is playing" % self._name)
    
    def watch_av(self):
        if self._age >=18:
            print("%s is watching AV" % self._name)
        else:
            print("%s can only watch HuLuWa" % self._name)

class Student(Person):
    def __init__(self, name, age, grade):
        super().__init__(name, age)
        self._grade = grade
    
    @property
    def grade(self):
        return self._grade
    
    @grade.setter
    def grade(self, grade):
        self._grade = grade
    
    def study(self, course):
        print("%s's %s is studying %s" % (self._grade, self._name, course))

class Teacher(Person):
    
    def __init__ (self, name, age, title):
        super().__init__(name, age)
        self._title = title
    
    @property
    def title(self):
        return self.title
    @title.setter
    def title(self, title):
        self._title = title
    
    def teach(self, course):
        print("%s %s is teaching %s" % (self._name, self._title, course))
        
        
def main():
    stu = Student("DaChui", 15, "High School")
    stu.study("Math")
    stu.watch_av()
    t = Teacher("Professor", 38, "Expert")
    t.watch_av()
    t.teach("Chinese")
main()
# Out:
# High School's DaChui is studying Math
# DaChui can only watch HuLuWa
# Professor is watching AV
# Professor Expert is teaching Chinese

# %%
from abc import ABCMeta, abstractmethod

class Pet(object, metaclass = ABCMeta):
    def __init__(self, nickname):
        self._nickname = nickname
    
    @abstractmethod
    def make_voice(self):
        pass

class Dog(Pet):
    def make_voice(self):
        print("%s: wang wang wang" % self._nickname)
        
class Cat(Pet):
    def make_voice(self):
        print("%s: miao miao miao" % self._nickname)

def main():
    pets = [Dog('Da Huang'), Cat("Kitty"), Dog("Er Huang")]
    for pet in pets:
        pet.make_voice()

main()
# Out:
# Da Huang: wang wang wang
# Kitty: miao miao miao
# Er Huang: wang wang wang

# %% [markdown]
# # 综合案例

# %%
from abc import ABCMeta, abstractmethod
from random import randint, randrange

class Fighter(object, metaclass= ABCMeta):
    
    __slot__ = ("_name", "_hp")
    
    def __init__(self, name, hp):
        
        self._name = name
        self._hp = hp
    @property
    def name(self):
        return self._name
    
    @property
    def hp(self):
        return self._hp
    
    @hp.setter
    def hp(self,hp):
        self._hp = hp if hp>=0 else 0
        
    @property
    def alive(self):
        return self._hp>0
    
    @abstractmethod
    def attack(self, other):
        pass
    
class Ultraman(Fighter):
    __slots__ = ("_name", "_hp", "_mp")
    
    def __init__(self, name, hp ,mp):
        super().__init__(name, hp)
        self._mp = mp
    
    def attack(self, other):
        other.hp -= randint(15,25)
    
    def huge_attack(self, other):
        
        if self._mp >=50:
            self._mp -=50
            injury = other.hp*3//4
            injury = injury if injury >=50 else 50
            other.hp -= injury
            
            return True
        else:
            self.attack(other)
            return False
    
    def magic_attack(self, others):
        if self._mp >= 20:
            self._mp -= 20
            for temp in others:
                if temp.alive:
                    temp.hp -= randint(10, 15)
                    
            return True
        else:
            return False
        
    def resume(self):
        incr_point = randint(1,10)
        self._mp += incr_point
        return incr_point
    
    def __str__(self):
        return "~~~ %s Ultraman ~~~ \n" % self._name +\
                "Health: %d\n" % self._hp+\
                "Mana: %d \n" % self._mp
    
class Monster(Fighter):
    __slots__ = ("_name", "_hp")
    def attack(self, other):
        other.hp -= randint(10,20)
    def __str__(self):
        return " ~~~ %s Monster ~~~\n" % self._name +\
                "Health: %d\n" % self._hp
    
def is_any_alive(monsters):
    for monster in monsters:
        if monster.alive>0:
            return True
    return False


def select_alive_one(monsters):
    monsters_len = len(monsters)
    while(True):
        index = randrange(monsters_len)
        monster = monsters[index]
        if monster.alive > 0:
            return monster

def display_info(ultraman, monsters):
    print(ultraman)
    for monster in monsters:
        print(monster, end=' ')

def main():
    u = Ultraman("DiJia Ultraman", 1000, 120)
    m1 = Monster("Monster-A", 250)
    m2 = Monster("Monster-B", 500)
    m3 = Monster("Monster-C", 750)
    ms = [m1,m2,m3]
    fight_round =1
    
    while u.alive and is_any_alive(ms):
            print("============== round # %02d ==============" % fight_round)
            
            m = select_alive_one(ms)
            skill = randint(1,10)
            if skill <= 6:
                print("%s is using attack to %s" % (u.name, m.name))
                u.attack(m)
                print("%s is resuming %s points" % (u.name, u.resume()))
                
            elif skill <= 9:
                if u.magic_attack(ms):
                    print("%s is using magic" % u.name)
                else:
                    print("%s's magic is failed" % u.name)
            else:
                if u.huge_attack(m):
                    print("%s uses huge attack the %s" %(u.name, m.name))
                else:
                    print("%s is using attack to %s" % (u.name, m.name))
                    print("%s is resuming %s points" % (u.name, u.resume()))
            if m.alive > 0:
                print("%s attack back to %s" %(m.name, u.name))
                m.attack(u)
            
            display_info(u,ms)
            fight_round +=1
    print("\n---------------fight over----------\n")
    if u.alive>0:
        print("Ultraman wins")
    else:
        print("Monster wins")
main()
# Out:
# ============== round # 01 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 6 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 989
# Mana: 126
#
#  ~~~ Monster-A Monster ~~~
# Health: 250
#   ~~~ Monster-B Monster ~~~
# Health: 478
#   ~~~ Monster-C Monster ~~~
# Health: 750
#  ============== round # 02 ==============
# DiJia Ultraman is using attack to Monster-A
# DiJia Ultraman is resuming 1 points
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 971
# Mana: 127
#
#  ~~~ Monster-A Monster ~~~
# Health: 230
#   ~~~ Monster-B Monster ~~~
# Health: 478
#   ~~~ Monster-C Monster ~~~
# Health: 750
#  ============== round # 03 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 955
# Mana: 107
#
#  ~~~ Monster-A Monster ~~~
# Health: 219
#   ~~~ Monster-B Monster ~~~
# Health: 468
#   ~~~ Monster-C Monster ~~~
# Health: 738
#  ============== round # 04 ==============
# DiJia Ultraman is using magic
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 939
# Mana: 87
#
#  ~~~ Monster-A Monster ~~~
# Health: 204
#   ~~~ Monster-B Monster ~~~
# Health: 453
#   ~~~ Monster-C Monster ~~~
# Health: 723
#  ============== round # 05 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 6 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 921
# Mana: 93
#
#  ~~~ Monster-A Monster ~~~
# Health: 204
#   ~~~ Monster-B Monster ~~~
# Health: 430
#   ~~~ Monster-C Monster ~~~
# Health: 723
#  ============== round # 06 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 7 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 904
# Mana: 100
#
#  ~~~ Monster-A Monster ~~~
# Health: 204
#   ~~~ Monster-B Monster ~~~
# Health: 408
#   ~~~ Monster-C Monster ~~~
# Health: 723
#  ============== round # 07 ==============
# DiJia Ultraman is using attack to Monster-A
# DiJia Ultraman is resuming 3 points
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 887
# Mana: 103
#
#  ~~~ Monster-A Monster ~~~
# Health: 182
#   ~~~ Monster-B Monster ~~~
# Health: 408
#   ~~~ Monster-C Monster ~~~
# Health: 723
#  ============== round # 08 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 867
# Mana: 83
#
#  ~~~ Monster-A Monster ~~~
# Health: 170
#   ~~~ Monster-B Monster ~~~
# Health: 393
#   ~~~ Monster-C Monster ~~~
# Health: 713
#  ============== round # 09 ==============
# DiJia Ultraman is using attack to Monster-A
# DiJia Ultraman is resuming 8 points
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 854
# Mana: 91
#
#  ~~~ Monster-A Monster ~~~
# Health: 154
#   ~~~ Monster-B Monster ~~~
# Health: 393
#   ~~~ Monster-C Monster ~~~
# Health: 713
#  ============== round # 10 ==============
# DiJia Ultraman is using attack to Monster-A
# DiJia Ultraman is resuming 7 points
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 835
# Mana: 98
#
#  ~~~ Monster-A Monster ~~~
# Health: 135
#   ~~~ Monster-B Monster ~~~
# Health: 393
#   ~~~ Monster-C Monster ~~~
# Health: 713
#  ============== round # 11 ==============
# DiJia Ultraman is using attack to Monster-A
# DiJia Ultraman is resuming 7 points
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 815
# Mana: 105
#
#  ~~~ Monster-A Monster ~~~
# Health: 115
#   ~~~ Monster-B Monster ~~~
# Health: 393
#   ~~~ Monster-C Monster ~~~
# Health: 713
#  ============== round # 12 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 6 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 795
# Mana: 111
#
#  ~~~ Monster-A Monster ~~~
# Health: 115
#   ~~~ Monster-B Monster ~~~
# Health: 369
#   ~~~ Monster-C Monster ~~~
# Health: 713
#  ============== round # 13 ==============
# DiJia Ultraman is using attack to Monster-A
# DiJia Ultraman is resuming 7 points
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 775
# Mana: 118
#
#  ~~~ Monster-A Monster ~~~
# Health: 98
#   ~~~ Monster-B Monster ~~~
# Health: 369
#   ~~~ Monster-C Monster ~~~
# Health: 713
#  ============== round # 14 ==============
# DiJia Ultraman is using attack to Monster-A
# DiJia Ultraman is resuming 10 points
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 762
# Mana: 128
#
#  ~~~ Monster-A Monster ~~~
# Health: 81
#   ~~~ Monster-B Monster ~~~
# Health: 369
#   ~~~ Monster-C Monster ~~~
# Health: 713
#  ============== round # 15 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 1 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 749
# Mana: 129
#
#  ~~~ Monster-A Monster ~~~
# Health: 81
#   ~~~ Monster-B Monster ~~~
# Health: 369
#   ~~~ Monster-C Monster ~~~
# Health: 696
#  ============== round # 16 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 10 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 730
# Mana: 139
#
#  ~~~ Monster-A Monster ~~~
# Health: 81
#   ~~~ Monster-B Monster ~~~
# Health: 369
#   ~~~ Monster-C Monster ~~~
# Health: 678
#  ============== round # 17 ==============
# DiJia Ultraman is using magic
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 711
# Mana: 119
#
#  ~~~ Monster-A Monster ~~~
# Health: 71
#   ~~~ Monster-B Monster ~~~
# Health: 357
#   ~~~ Monster-C Monster ~~~
# Health: 665
#  ============== round # 18 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 8 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 701
# Mana: 127
#
#  ~~~ Monster-A Monster ~~~
# Health: 71
#   ~~~ Monster-B Monster ~~~
# Health: 334
#   ~~~ Monster-C Monster ~~~
# Health: 665
#  ============== round # 19 ==============
# DiJia Ultraman is using magic
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 686
# Mana: 107
#
#  ~~~ Monster-A Monster ~~~
# Health: 57
#   ~~~ Monster-B Monster ~~~
# Health: 321
#   ~~~ Monster-C Monster ~~~
# Health: 652
#  ============== round # 20 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 7 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 668
# Mana: 114
#
#  ~~~ Monster-A Monster ~~~
# Health: 57
#   ~~~ Monster-B Monster ~~~
# Health: 296
#   ~~~ Monster-C Monster ~~~
# Health: 652
#  ============== round # 21 ==============
# DiJia Ultraman is using attack to Monster-A
# DiJia Ultraman is resuming 7 points
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 656
# Mana: 121
#
#  ~~~ Monster-A Monster ~~~
# Health: 42
#   ~~~ Monster-B Monster ~~~
# Health: 296
#   ~~~ Monster-C Monster ~~~
# Health: 652
#  ============== round # 22 ==============
# DiJia Ultraman is using magic
# Monster-A attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 638
# Mana: 101
#
#  ~~~ Monster-A Monster ~~~
# Health: 30
#   ~~~ Monster-B Monster ~~~
# Health: 286
#   ~~~ Monster-C Monster ~~~
# Health: 637
#  ============== round # 23 ==============
# DiJia Ultraman uses huge attack the Monster-A
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 638
# Mana: 51
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 286
#   ~~~ Monster-C Monster ~~~
# Health: 637
#  ============== round # 24 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 3 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 625
# Mana: 54
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 266
#   ~~~ Monster-C Monster ~~~
# Health: 637
#  ============== round # 25 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 5 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 613
# Mana: 59
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 266
#   ~~~ Monster-C Monster ~~~
# Health: 617
#  ============== round # 26 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 600
# Mana: 39
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 256
#   ~~~ Monster-C Monster ~~~
# Health: 603
#  ============== round # 27 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 1 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 584
# Mana: 40
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 256
#   ~~~ Monster-C Monster ~~~
# Health: 585
#  ============== round # 28 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 565
# Mana: 20
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 246
#   ~~~ Monster-C Monster ~~~
# Health: 572
#  ============== round # 29 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 2 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 554
# Mana: 22
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 246
#   ~~~ Monster-C Monster ~~~
# Health: 554
#  ============== round # 30 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 1 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 539
# Mana: 23
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 226
#   ~~~ Monster-C Monster ~~~
# Health: 554
#  ============== round # 31 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 522
# Mana: 3
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 212
#   ~~~ Monster-C Monster ~~~
# Health: 539
#  ============== round # 32 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 6 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 503
# Mana: 9
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 212
#   ~~~ Monster-C Monster ~~~
# Health: 518
#  ============== round # 33 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 2 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 490
# Mana: 11
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 212
#   ~~~ Monster-C Monster ~~~
# Health: 497
#  ============== round # 34 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 1 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 479
# Mana: 12
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 196
#   ~~~ Monster-C Monster ~~~
# Health: 497
#  ============== round # 35 ==============
# DiJia Ultraman's magic is failed
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 460
# Mana: 12
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 196
#   ~~~ Monster-C Monster ~~~
# Health: 497
#  ============== round # 36 ==============
# DiJia Ultraman's magic is failed
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 441
# Mana: 12
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 196
#   ~~~ Monster-C Monster ~~~
# Health: 497
#  ============== round # 37 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 1 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 427
# Mana: 13
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 196
#   ~~~ Monster-C Monster ~~~
# Health: 472
#  ============== round # 38 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 8 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 416
# Mana: 21
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 178
#   ~~~ Monster-C Monster ~~~
# Health: 472
#  ============== round # 39 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 4 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 401
# Mana: 25
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 154
#   ~~~ Monster-C Monster ~~~
# Health: 472
#  ============== round # 40 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 4 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 381
# Mana: 29
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 154
#   ~~~ Monster-C Monster ~~~
# Health: 447
#  ============== round # 41 ==============
# DiJia Ultraman is using magic
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 368
# Mana: 9
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 142
#   ~~~ Monster-C Monster ~~~
# Health: 434
#  ============== round # 42 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 1 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 356
# Mana: 10
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 117
#   ~~~ Monster-C Monster ~~~
# Health: 434
#  ============== round # 43 ==============
# DiJia Ultraman's magic is failed
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 337
# Mana: 10
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 117
#   ~~~ Monster-C Monster ~~~
# Health: 434
#  ============== round # 44 ==============
# DiJia Ultraman's magic is failed
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 320
# Mana: 10
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 117
#   ~~~ Monster-C Monster ~~~
# Health: 434
#  ============== round # 45 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 3 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 303
# Mana: 13
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 117
#   ~~~ Monster-C Monster ~~~
# Health: 411
#  ============== round # 46 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 9 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 293
# Mana: 22
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 117
#   ~~~ Monster-C Monster ~~~
# Health: 395
#  ============== round # 47 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 280
# Mana: 2
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 102
#   ~~~ Monster-C Monster ~~~
# Health: 384
#  ============== round # 48 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 9 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 270
# Mana: 11
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 102
#   ~~~ Monster-C Monster ~~~
# Health: 365
#  ============== round # 49 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 9 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 258
# Mana: 20
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 79
#   ~~~ Monster-C Monster ~~~
# Health: 365
#  ============== round # 50 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 10 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 242
# Mana: 30
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 79
#   ~~~ Monster-C Monster ~~~
# Health: 342
#  ============== round # 51 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 5 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 224
# Mana: 35
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 79
#   ~~~ Monster-C Monster ~~~
# Health: 318
#  ============== round # 52 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 9 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 206
# Mana: 44
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 79
#   ~~~ Monster-C Monster ~~~
# Health: 295
#  ============== round # 53 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 191
# Mana: 24
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 66
#   ~~~ Monster-C Monster ~~~
# Health: 280
#  ============== round # 54 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 4 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 173
# Mana: 28
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 66
#   ~~~ Monster-C Monster ~~~
# Health: 262
#  ============== round # 55 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 155
# Mana: 8
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 56
#   ~~~ Monster-C Monster ~~~
# Health: 247
#  ============== round # 56 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 7 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 135
# Mana: 15
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 38
#   ~~~ Monster-C Monster ~~~
# Health: 247
#  ============== round # 57 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 1 points
# Monster-B attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 115
# Mana: 16
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 15
#   ~~~ Monster-C Monster ~~~
# Health: 247
#  ============== round # 58 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 7 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 100
# Mana: 23
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 15
#   ~~~ Monster-C Monster ~~~
# Health: 228
#  ============== round # 59 ==============
# DiJia Ultraman is using attack to Monster-B
# DiJia Ultraman is resuming 9 points
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 100
# Mana: 32
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 0
#   ~~~ Monster-C Monster ~~~
# Health: 228
#  ============== round # 60 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 6 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 84
# Mana: 38
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 0
#   ~~~ Monster-C Monster ~~~
# Health: 212
#  ============== round # 61 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 66
# Mana: 18
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 0
#   ~~~ Monster-C Monster ~~~
# Health: 202
#  ============== round # 62 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 5 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 56
# Mana: 23
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 0
#   ~~~ Monster-C Monster ~~~
# Health: 184
#  ============== round # 63 ==============
# DiJia Ultraman is using magic
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 37
# Mana: 3
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 0
#   ~~~ Monster-C Monster ~~~
# Health: 170
#  ============== round # 64 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 1 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 26
# Mana: 4
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 0
#   ~~~ Monster-C Monster ~~~
# Health: 150
#  ============== round # 65 ==============
# DiJia Ultraman's magic is failed
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 12
# Mana: 4
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 0
#   ~~~ Monster-C Monster ~~~
# Health: 150
#  ============== round # 66 ==============
# DiJia Ultraman is using attack to Monster-C
# DiJia Ultraman is resuming 3 points
# Monster-C attack back to DiJia Ultraman
# ~~~ DiJia Ultraman Ultraman ~~~
# Health: 0
# Mana: 7
#
#  ~~~ Monster-A Monster ~~~
# Health: 0
#   ~~~ Monster-B Monster ~~~
# Health: 0
#   ~~~ Monster-C Monster ~~~
# Health: 132
#
# ---------------fight over----------
#
# Monster wins

# %% [markdown]
# # 案例2：扑克游戏

# %%
import random

class Card(object):
    def __init__(self,suite, face):
        self._suite = suite
        self._face = face
    
    @property
    def face(self):
        return self._face
    
    @property
    def suite(self):
        return self._suite
    
    def __str__(self):
        if self._face == 1:
            face_str = "A"
        elif self._face == 11:
            face_str = "J"
        elif self._face == 12:
            face_str = "Q"
        elif self._face ==13:
            face_str = "K"
        else:
            face_str = str(self._face)
        return '%s%s' %(self._suite, face_str)
    
    def __repr__(self):
        return self.__str__()
    
class Poker(object):
    def __init__(self):
        self._cards = [Card(suite, face) 
                       for suite in '♠♥♣♦'
                       for face in range(1, 14)]
        self._current = 0
        
    @property
    def cards(self):
        return self._cards
    
    def shuffle(self):
        self._current = 0
        random.shuffle(self._cards)
    
    @property
    def next(self):
        card = self._cards[self._current]
        self._current += 1
        return card
    
    @property
    def has_next(self):
        return self._current <len(self._cards)

class Player(object):
    def __init__(self, name):
        self._name = name
        self._cards_on_hand = []
        
    @property
    def name(self):
        return self._name
    
    @property
    def cards_on_hand(self):
        return self._cards_on_hand
    
    def get(self,card):
        self._cards_on_hand.append(card )
        
    def arrange(self, card_key):
        self._cards_on_hand.sort(key= card_key)
    
def get_key(card):
    return (card.suite, card.face)

def main():
    p = Poker()
    p.shuffle()
    players = [Player("A"),Player("B"),Player("C"),Player("D")]
    
    for _ in range(13):
        for player in players:
            player.get(p.next)
    
    for player in players:
        print(player.name+":", end='')
        player.arrange(get_key)
        print(player.cards_on_hand)

main()
# Out:
# A:[♠A, ♠3, ♠8, ♣3, ♣4, ♣6, ♣10, ♣J, ♣K, ♥2, ♥J, ♦A, ♦6]
# B:[♠6, ♠9, ♣2, ♣9, ♥3, ♥5, ♥6, ♥7, ♥Q, ♥K, ♦2, ♦8, ♦10]
# C:[♠4, ♠Q, ♣A, ♣7, ♣8, ♣Q, ♥8, ♥9, ♥10, ♦3, ♦4, ♦5, ♦9]
# D:[♠2, ♠5, ♠7, ♠10, ♠J, ♠K, ♣5, ♥A, ♥4, ♦7, ♦J, ♦Q, ♦K]

# %% [markdown]
# # 案例3：工资结算系统

# %%
from abc import ABCMeta, abstractmethod

class Employee(object, metaclass=ABCMeta):
    def __init__(self, name):
        self._name = name
    
    @property
    def name(self):
        return self.name
    
    @abstractmethod
    def get_salary(self):
        pass
    
class Manager(Employee):
    def get_salary(self):
        return 15000
    
class Programmer(Employee):
    def __init__(self,name, working_hour=0):
        super().__init__(name)
        self._working_hour = working_hour
        
    @property
    def working_hour(self):
        return self._working_hour
    
    @working_hour.setter
    def working_hour(self, working_hour):
        self._working_hour = working_hour if working_hour>0 else 0
        
    def get_salary(self):
        return 150 * self._working_hour
        

class Salesman(Employee):
    def __init__(self, name, sales = 0):
        self._name = name
        self._sales = sales
        
    @property
    def sales(self):
        return self._sales
    
    @sales.setter
    def sales(self, sales):
        self._sales = sales if sales>0 else 0
        
    def get_salary(self):
        return 1200 + self._sales*0.05

def main():
    emps = [
        Manager('刘备'), Programmer('诸葛亮'),
        Manager('曹操'), Salesman('荀彧'),
        Salesman('吕布'), Programmer('张辽'),
        Programmer('赵云')
    ]
    
    for emp in emps:
        if isinstance(emp, Programmer):
            emp.working_hour = int(input("Please input %s's working hour:" % emp.name))
        elif isinstance(emp, Salesman):
            emp.sales = int(input("Plase int %'s sales:'" % emp.name))
        
        print("%s's salary is: %s" %(emp.name, emp.get_salary))
main()
